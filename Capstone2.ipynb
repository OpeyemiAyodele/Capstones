# %%
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

listings = pd.read_csv('/Users/OpeyemiAyodele/Desktop/Data Analyst Tools/Capstones/Cap 2/listings (1).csv', delimiter=",")

reviews = pd.read_csv('/Users/OpeyemiAyodele/Desktop/Data Analyst Tools/Capstones/Cap 2/reviews 2.csv', delimiter=",")

# %%
listings.head()
# Out:
#       id                                name  host_id    host_name  \
# 0   6400                    The Studio Milan    13822    Francesca
# 1  17232         MPX-Center-EXPO Value/Money    66856       Simone
# 2  23986     " Characteristic Milanese flat"    95941       Jeremy
# 3  28300             nice flat near the park   121663        Marta
# 4  32119  Nico & Cynthia's Easy Yellow Suite   138683  Nico&Cinzia
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN       TIBALDI  45.44195    9.17797     Private room
# 1                  NaN        BOVISA  45.50465    9.16087      Shared room
# 2                  NaN       NAVIGLI  45.44991    9.17597  Entire home/apt
# 3                  NaN         SARPI  45.47814    9.17294     Private room
# 4                  NaN   VIALE MONZA  45.51988    9.22310  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19922 entries, 0 to 19921
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19922 non-null  int64
#  1   name                            19910 non-null  object
#  2   host_id                         19922 non-null  int64
#  3   host_name                       19918 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   19922 non-null  object
#  6   latitude                        19922 non-null  float64
#  7   longitude                       19922 non-null  float64
#  8   room_type                       19922 non-null  object
#  9   price                           19922 non-null  int64
#  10  minimum_nights                  19922 non-null  int64
#  11  number_of_reviews               19922 non-null  int64
# ...

# %%
reviews.head(20)
# Out:
#     listing_id         id        date  reviewer_id   reviewer_name  \
# 0         6400      36772  2010-04-19        94463            Hyun
# 1         6400     227727  2011-04-16       415910             Tej
# 2         6400    1162608  2012-04-22       415910             Tej
# 3         6400   11670681  2014-04-11      8464658        Isabelle
# 4         6400   11780336  2014-04-14      5427294          Hatice
# 5         6400   30074708  2015-04-17       415910             Tej
# 6         6400   47340535  2015-09-18      5023643           Glynn
# 7         6400   70088360  2016-04-16       415910             Tej
# 8         6400  142442322  2017-04-08       415910             Tej
# 9         6400  195594668  2017-09-20     30261686           Robin
# 10        6400  255658085  2018-04-21       415910             Tej
# 11        6400  436547910  2019-04-13       415910             Tej
# 12       17232      36164  2010-04-17       106656           Paolo
# ...

# %%
# !pip install googletrans

# %%
import googletrans
from googletrans import Translator

# %%
medianprice = listings.groupby('neighbourhood')[['price']].median()

# %%
medianprice
# Out:
#                price
# neighbourhood
# ADRIANO         51.0
# AFFORI          60.0
# BAGGIO          45.0
# BANDE NERE      60.0
# BARONA          50.0
# ...              ...
# VIALE MONZA     56.0
# VIGENTINA       80.0
# VILLAPIZZONE    56.0
# WASHINGTON      85.0
# XXII MARZO      85.0
#
# [87 rows x 1 columns]

# %%
listings.head()
# Out:
#       id                                name  host_id    host_name  \
# 0   6400                    The Studio Milan    13822    Francesca
# 1  17232         MPX-Center-EXPO Value/Money    66856       Simone
# 2  23986     " Characteristic Milanese flat"    95941       Jeremy
# 3  28300             nice flat near the park   121663        Marta
# 4  32119  Nico & Cynthia's Easy Yellow Suite   138683  Nico&Cinzia
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN       TIBALDI  45.44195    9.17797     Private room
# 1                  NaN        BOVISA  45.50465    9.16087      Shared room
# 2                  NaN       NAVIGLI  45.44991    9.17597  Entire home/apt
# 3                  NaN         SARPI  45.47814    9.17294     Private room
# 4                  NaN   VIALE MONZA  45.51988    9.22310  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
medianprice_sorted = medianprice.sort_values(['price'], ascending=False)

# %%
medianprice_sorted
# Out:
#                         price
# neighbourhood
# QUINTOSOLE              249.0
# GIARDINI PORTA VENEZIA  149.0
# DUOMO                   130.0
# PARCO SEMPIONE          120.0
# BRERA                   120.0
# ...                       ...
# PARCO NORD               45.0
# BAGGIO                   45.0
# CANTALUPA                41.5
# STEPHENSON               32.0
# RONCHETTO DELLE RANE     15.0
#
# [87 rows x 1 columns]

# %%
medianprice_sorted.reset_index()
# Out:
#              neighbourhood  price
# 0               QUINTOSOLE  249.0
# 1   GIARDINI PORTA VENEZIA  149.0
# 2                    DUOMO  130.0
# 3           PARCO SEMPIONE  120.0
# 4                    BRERA  120.0
# ..                     ...    ...
# 82              PARCO NORD   45.0
# 83                  BAGGIO   45.0
# 84               CANTALUPA   41.5
# 85              STEPHENSON   32.0
# 86    RONCHETTO DELLE RANE   15.0
#
# [87 rows x 2 columns]

# %%
sumprice = listings.groupby('neighbourhood')[['price']].sum()

# %%
sumprice
# Out:
#                price
# neighbourhood
# ADRIANO         5114
# AFFORI         11594
# BAGGIO          3205
# BANDE NERE     30795
# BARONA          2477
# ...              ...
# VIALE MONZA    16112
# VIGENTINA      40751
# VILLAPIZZONE   26535
# WASHINGTON     56495
# XXII MARZO     77766
#
# [87 rows x 1 columns]

# %%
sumprice_sorted = sumprice.sort_values(['price'], ascending=False)

# %%
sumprice_sorted
# Out:
#                          price
# neighbourhood
# DUOMO                   208743
# BUENOS AIRES - VENEZIA  188222
# BRERA                   183161
# NAVIGLI                 118950
# SARPI                   110834
# ...                        ...
# MUGGIANO                   260
# QUINTOSOLE                 249
# PARCO AGRICOLO SUD         100
# STEPHENSON                  32
# RONCHETTO DELLE RANE        15
#
# [87 rows x 1 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19922 entries, 0 to 19921
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19922 non-null  int64
#  1   name                            19910 non-null  object
#  2   host_id                         19922 non-null  int64
#  3   host_name                       19918 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   19922 non-null  object
#  6   latitude                        19922 non-null  float64
#  7   longitude                       19922 non-null  float64
#  8   room_type                       19922 non-null  object
#  9   price                           19922 non-null  int64
#  10  minimum_nights                  19922 non-null  int64
#  11  number_of_reviews               19922 non-null  int64
# ...

# %%
averageprice = listings.groupby('neighbourhood')[['price']].mean()

# %%
averageprice
# Out:
#                     price
# neighbourhood
# ADRIANO         86.677966
# AFFORI          85.881481
# BAGGIO          54.322034
# BANDE NERE      88.237822
# BARONA          68.805556
# ...                   ...
# VIALE MONZA     76.360190
# VIGENTINA      131.880259
# VILLAPIZZONE    81.146789
# WASHINGTON     132.306792
# XXII MARZO     126.243506
#
# [87 rows x 1 columns]

# %%
averageprice_sorted = averageprice.sort_values(['price'], ascending=False)

# %%
averageprice_sorted
# Out:
#                              price
# neighbourhood
# GIARDINI PORTA VENEZIA  455.142857
# QUINTOSOLE              249.000000
# GHISOLFA                232.539823
# BRERA                   221.208937
# DUOMO                   196.556497
# ...                            ...
# BAGGIO                   54.322034
# PARCO NORD               52.000000
# COMASINA                 49.032258
# STEPHENSON               32.000000
# RONCHETTO DELLE RANE     15.000000
#
# [87 rows x 1 columns]

# %%
x = listings['price'].values
x
# Out:
# array([100,  24, 150, ..., 100,  33,  50])

# %%
sns.set(rc={'figure.figsize': (16,3)})

# %%
sns.boxplot(x)
